# %% [markdown]
# ***Oops***

# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)?
#
# -->
# Object-Oriented Programming is a programming paradigm that organizes code using objects and classes rather than functions and logic alone.
#
# In OOP, real-world entities like cars, students, and accounts are represented as objects, and their characteristics and behaviors are defined using classes.
#
# Main principles of OOP:
#
# -Encapsulation
#
# -Inheritance
#
# -Polymorphism
#
# -Abstraction
#
#
#
# 2. What is a Class in OOP?
#
#
# -->  A class is a blueprint or template used to create objects.
#
# It defines:
#
# -Attributes (variables)
#
# -Methods (functions)
#
#
#
# 3. What is an Object in OOP?
#
# An object is an instance of a class.
# It represents a real-world entity and can use the class's methods and variables.
#
#
# 4. Difference between Abstraction and Encapsulation
#
# Abstraction                        Encapsulation
#
# -Hides implementation details      - Hides data
#
# -Shows only necessary features    	-Protects variables
#
# -Achieved using abstract classes    - Achieved using private variables
#
# Example:
#
# Abstraction: Car shows steering and brake but hides engine mechanism.
#
# Encapsulation: Protecting data inside a class.
#
#
# 5. What are Dunder Methods in Python?
#
#
# --> Dunder methods are special methods in Python that begin and end with double underscores.
#
# Example:
#
# __init__
#
# __str__
#
# __add__
#
# They allow objects to use built-in operations.
#
# Example:
#
# class A:
#
#     def __init__(self):
#
#         print("Constructor called")
#
#
# 6. Explain the Concept of Inheritance.
#
#
# --> Inheritance allows a class to inherit properties and methods from another class.
#
# Parent class → Base class
#
# Child class → Derived class
#
# Example:
#
# class Animal:
#
#     def eat(self):
#
#         print("Animal eats")
#
# class Dog(Animal):
#
#     def bark(self):
#
#         print("Dog barks")
#
# Dog inherits from Animal.
#
#
# 7. What is Polymorphism in OOP?
#
#
# Polymorphism means one name, multiple forms.
# The same function can behave differently for different objects.
#
# Example:
#
# print(len("Hello"))
# print(len([1,2,3]))
#
#
# 8. How is Encapsulation Achieved in Python?
#
#
# Encapsulation is achieved by using private variables and getter/setter methods.
# Example:
#
#
# class Bank:
#
#     def __init__(self):
#
#         self.__balance = 1000
#
# __balance is private and cannot be accessed directly.
#
#
# 9. What is a Constructor in Python?
#
# A constructor is a special method used to initialize objects.
# In Python, it is:
#
# __init__()
#
# Example:
#
# class Student:
#
#     def __init__(self, name):
#
#         self.name = name
#
#
# 10. What are Class Methods and Static Methods?
#
# --> Class Method
#
# Works with class variables.
#
# Uses decorator:
#
# @classmethod
#
# Example:
#
# class A:
#     @classmethod
#     def show(cls):
#         print("Class method")
#
# --> Static Method
#
# Independent of class and object.
#
# Uses decorator:
#
# @staticmethod
#
# Example:
#
# class A:
#     @staticmethod
#     def show():
#         print("Static method")
#
#
# 11. What is Method Overloading in Python?
#
#
# -->  Method overloading means defining multiple methods with the same name but different parameters.
# Python does not support traditional overloading but it can be simulated.
#
# Example:
#
# def add(a, b=0):
#     return a + b
#
#
# 12. What is Method Overriding?
#
# -->  Method overriding occurs when a child class redefines a method of the parent class.
#
# Example:
#
# class Animal:
#     def sound(self):
#         print("Animal sound")
#
# class Dog(Animal):
#     def sound(self):
#         print("Dog barks")
#
#
# 13. What is Property Decorator in Python?
#
# The @property decorator allows a method to be accessed like an attribute.
#
# Example:
#
# class A:
#     @property
#     def show(self):
#         return "Hello"
#
# Access:
#
# obj.show
#
#
# 14. Why is Polymorphism Important?
#
#
# Polymorphism is important because it:
#
# -Improves code flexibility
#
# -Enables method reuse
#
# -Allows same interface for different objects
#
#
# 15. What is an Abstract Class in Python?
#
# An abstract class is a class that cannot be instantiated and contains abstract methods.
# It is created using ABC module.
#
# Example:
#
# from abc import ABC, abstractmethod
#
# class Shape(ABC):
#     @abstractmethod
#     def area(self):
#         pass
#
#
# 16. Advantages of OOP
#
# -Code reusability
#
# -Better program structure
#
# -Easier debugging
#
# -Data security
#
# -Modularity
#
# 17. What is Multiple Inheritance?
#
#
# Multiple inheritance means a class inherits from more than one parent class.
# Example:
#
# class A:
#     pass
# class B:
#     pass
# class C(A, B):
#     pass
#
#
# 18. Difference between Class Variable and Instance Variable
#
# -->
#  Class Variable	           Instance Variable
#
# Shared by all objects	      Unique for each object
#
# Defined inside class	      Defined using self
#
# Memory efficient	          Stored per object
#
# Example:
#
# class A:
#     x = 10   # class variable
#     def __init__(self):
#         self.y = 20   # instance variable
#
#
# 19. Purpose of __str__ and __repr__
#
# -->
#
# __str__
#
# Provides readable output for users.
#
# Example:
#
# def __str__(self):
#     return "Student object"
#
#
# __repr__
#
# Provides developer-friendly representation.
#
# Example:
#
# def __repr__(self):
#     return "Student()"
#
#
# 20. Significance of super() Function.
#
# -->
#
# super() allows a child class to call methods of the parent class.
#
# Example:
#
# class A:
#
#     def show(self):
#         print("A")
# class B(A):
#
#     def show(self):
#         super().show()
#         print("B")
#
#
# 21. Significance of __del__ Method
#
# -->
#
# __del__ is a destructor method called when an object is deleted.
#
# Example:
#
# def __del__(self):
#     print("Object destroyed")
#
#
# 22. Difference Between @staticmethod and @classmethod
#
# -->
# Static Method           	           Class Method
#
# No access to class or instance	      Access to class
#
# Uses @staticmethod                  	Uses @classmethod
#
# No cls parameter	                    Uses cls parameter
#
#
# 23. How Polymorphism Works with Inheritance?
#
# -->
# Polymorphism works when child classes override parent methods.
#
# Example:
#
# class Bird:
#     def fly(self):
#         print("Bird flies")
#
# class Sparrow(Bird):
#     def fly(self):
#         print("Sparrow flies fast")
#
#
# 24. What is Method Chaining?
#
# -->
#
# Method chaining means calling multiple methods in a single statement.
#
# Example:
#
# class A:
#     def add(self, x):
#         self.x = x
#         return self
#     def show(self):
#         print(self.x)
#
# A().add(10).show()
#
#
# 25. Purpose of __call__ Method
#
# -->
#
# __call__ allows an object to be called like a function.
#
# Example:
#
# class A:
#     def __call__(self):
#         print("Object called like function")
#
# obj = A()
# obj()

# %%
# Practical Questions

# %%
"""1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
that overrides the speak() method to print "Bark!" """


class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

d = Dog()
d.speak()
# Out:
# Bark!

# %%
"""2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
from it and implement the area() method in both."""
from abc import ABC, abstractmethod
import math

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

class Circle(Shape):

    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius * self.radius

class Rectangle(Shape):

    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

c = Circle(5)
r = Rectangle(4,6)

print(c.area())
print(r.area())



"""3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
and further derive a class ElectricCar that adds a battery attribute."""

class Vehicle:

    def __init__(self, type):
        self.type = type

class Car(Vehicle):

    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

class ElectricCar(Car):

    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

car = ElectricCar("Car", "Tesla", "75kWh")

print(car.type)
print(car.brand)
print(car.battery)



"""4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
Sparrow and Penguin that override the fly() method. """


class Bird:

    def fly(self):
        print("Bird can fly")

class Sparrow(Bird):

    def fly(self):
        print("Sparrow flies high")

class Penguin(Bird):

    def fly(self):
        print("Penguin cannot fly")

b1 = Sparrow()
b2 = Penguin()

b1.fly()
b2.fly()


"""5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
balance and methods to deposit, withdraw, and check balance."""

class BankAccount:

    def __init__(self, balance):
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        self.__balance -= amount

    def check_balance(self):
        print("Balance:", self.__balance)

acc = BankAccount(1000)
acc.deposit(500)
acc.withdraw(200)
acc.check_balance()


"""6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
and Piano that implement their own version of play()."""

class Instrument:

    def play(self):
        print("Instrument is playing")

class Guitar(Instrument):

    def play(self):
        print("Playing Guitar")

class Piano(Instrument):

    def play(self):
        print("Playing Piano")

g = Guitar()
p = Piano()

g.play()
p.play()


"""7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
method subtract_numbers() to subtract two numbers."""

class MathOperations:

    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print(MathOperations.add_numbers(5,3))
print(MathOperations.subtract_numbers(10,4))

"""8. Implement a class Person with a class method to count the total number of persons created."""

class Person:

    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

p1 = Person("A")
p2 = Person("B")

print(Person.total_persons())


"""9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
fraction as "numerator/denominator"."""

class Fraction:

    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

f = Fraction(3,4)
print(f)


"""10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
vectors."""

class Vector:

    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x},{self.y})"

v1 = Vector(2,3)
v2 = Vector(4,5)

v3 = v1 + v2

print(v3)


"""11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
{name} and I am {age} years old." """

class Person:

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p = Person("Anshika",20)
p.greet()


"""12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
the average of the grades."""

class Student:

    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

s = Student("Aman",[80,85,90])
print(s.average_grade())


"""13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
area."""

class Rectangle:

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

r = Rectangle()
r.set_dimensions(5,4)

print(r.area())


"""14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
and hourly rate. Create a derived class Manager that adds a bonus to the salary."""
class Employee:

    def calculate_salary(self, hours, rate):
        return hours * rate

class Manager(Employee):

    def calculate_salary(self, hours, rate, bonus):
        return hours * rate + bonus

e = Employee()
m = Manager()

print(e.calculate_salary(40,20))
print(m.calculate_salary(40,20,500))


"""15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
calculates the total price of the product."""
class Product:

    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

p = Product("Laptop",50000,2)
print(p.total_price())

"""16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
implement the sound() method."""
from abc import ABC, abstractmethod

class Animal(ABC):

    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):

    def sound(self):
        print("Moo")

class Sheep(Animal):

    def sound(self):
        print("Baa")

c = Cow()
s = Sheep()

c.sound()
s.sound()

"""
17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
returns a formatted string with the book's details."""
class Book:

    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year

    def get_book_info(self):
        return f"{self.title} by {self.author}, published in {self.year}"

b = Book("Python Basics","John",2022)
print(b.get_book_info())

"""18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms."""
class House:

    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):

    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

m = Mansion("Delhi",5000000,10)

print(m.address)
print(m.price)
print(m.number_of_rooms)
# Out:
# 78.53981633974483
# 24
# Car
# Tesla
# 75kWh
# Sparrow flies high
# Penguin cannot fly
# Balance: 1300
# Playing Guitar
# Playing Piano
# 8
# 6
# 2
# 3/4
# (6,8)
# Hello, my name is Anshika and I am 20 years old.
# 85.0
# 20
# 800
# 1300
# 100000
# Moo
# Baa
# Python Basics by John, published in 2022
# Delhi
# 5000000
# 10
